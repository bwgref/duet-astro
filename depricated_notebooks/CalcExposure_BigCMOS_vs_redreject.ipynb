# %%
import astropy.units as u
from tdsat_telescope import load_telescope_parameters
from tdsat_sensitivity import src_rate, bgd_sky_qe_rate, bgd_electronics, calc_exposure
from tdsat_neff import get_neff
from duet_filters import optimize_filter
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
siglimit = 10. # sigma
read_noise = 3.*(2**0.5) # Read noise for two frames

# Target value
AB = 22*u.ABmag

point_drift = 1*u.arcsec # To be added to the PSF in quadrature
point_jitter = 2*u.arcsec
# Define bands
td1_band = [193, 233]*u.nm


#td1_band = [260, 300]*u.nm



# Transmission efficiency
trans_eff = (0.975)**8 # from Jim. 
reflectivity = 0.80 # From the curve in Jim's slides
filter_target = 0.5

# trans_eff = 1.0
# reflectivity=1.0


print('Transmission efficiency: {}'.format(trans_eff))
print('Reflectivity: {}'.format(reflectivity))
# Out:
# Transmission efficiency: 0.8166518036622619
# Reflectivity: 0.8

# %%
# Loop for low zodiacal background
siglimit=10.

config = 12
diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=False)


# Add pointing drift to the PSF in quadrature.
psf_size = (psf_size**2 + point_drift**2 + point_jitter**2)**0.5


#     print()
#     print('Band Average QE: {}'.format(qe))
#     print('Effective PSF size {}'.format(psf_size))
# Get the number of effective background pixels
neff = get_neff(psf_size, pixel_size)
#     print('Number of effective bgd pixels: {}'.format(neff))
#     print()

all_exp = []
all_rej = []
for filter_target in np.arange(50)*0.5 + 0.5:
    rej = optimize_filter(td1_band[0], td1_band[1], target_ratio = filter_target, blue_filter=False)
    all_rej = np.append(all_rej, rej)
    
    trans_loss = (1 + 0.1 * np.log10(rej))
    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,
                                  diameter=diameter,
                                  band=td1_band,filter_target=filter_target,
                                  pixel_size=pixel_size)
    bgd_cps = trans_loss*trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Target Ratio: {}'.format(filter_target))
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_loss*trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
    all_exp = np.append(all_exp, exposure)
# Out:
# Target Ratio: 0.5
# Sky background rate per pixel: 0.002422827581978019 1 / s
# Source Photon Rate: 0.1610850181023931 1 / s
#
# Exposure Required: 833.3468304217026 s
# ---------
#
#
# Target Ratio: 1.0
# Sky background rate per pixel: 0.0033855766221605023 1 / s
# Source Photon Rate: 0.16866505392043 1 / s
#
# Exposure Required: 801.4744566640693 s
# ---------
#
#
# Target Ratio: 1.5
# Sky background rate per pixel: 0.004345632780838856 1 / s
# Source Photon Rate: 0.17309909062810483 1 / s
#
# Exposure Required: 786.3946482130145 s
# ---------
#
#
# Target Ratio: 2.0
# Sky background rate per pixel: 0.005311496435974813 1 / s
# Source Photon Rate: 0.17624508973846692 1 / s
#
# Exposure Required: 777.7241100022558 s
# ---------
#
#
# Target Ratio: 2.5
# Sky background rate per pixel: 0.0062842006999702885 1 / s
# Source Photon Rate: 0.17868531622854553 1 / s
#
# Exposure Required: 772.4097041133116 s
# ---------
#
#
# Target Ratio: 3.0
# Sky background rate per pixel: 0.007263517444137158 1 / s
# Source Photon Rate: 0.18067912644614179 1 / s
#
# Exposure Required: 769.147051761192 s
# ---------
#
#
# Target Ratio: 3.5
# Sky background rate per pixel: 0.008248965391468988 1 / s
# Source Photon Rate: 0.182364868965532 1 / s
#
# Exposure Required: 767.2621440839819 s
# ---------
#
#
# Target Ratio: 4.0
# Sky background rate per pixel: 0.009240044861733654 1 / s
# Source Photon Rate: 0.1838251255565039 1 / s
#
# Exposure Required: 766.3629782160211 s
# ---------
#
#
# Target Ratio: 4.5
# Sky background rate per pixel: 0.010236297377635654 1 / s
# Source Photon Rate: 0.18511316315381657 1 / s
#
# Exposure Required: 766.2022297342157 s
# ---------
#
#
# Target Ratio: 5.0
# Sky background rate per pixel: 0.011237317272854108 1 / s
# Source Photon Rate: 0.18626535204658246 1 / s
#
# Exposure Required: 766.6142528881682 s
# ---------
#
#
# Target Ratio: 5.5
# Sky background rate per pixel: 0.0122427493103748 1 / s
# Source Photon Rate: 0.18730763368171327 1 / s
#
# Exposure Required: 767.4829079487087 s
# ---------
#
#
# Target Ratio: 6.0
# Sky background rate per pixel: 0.013252282633544844 1 / s
# Source Photon Rate: 0.18825916226417866 1 / s
#
# Exposure Required: 768.7237566284018 s
# ---------
#
#
# Target Ratio: 6.5
# Sky background rate per pixel: 0.014265644344953825 1 / s
# Source Photon Rate: 0.18913448370838906 1 / s
#
# Exposure Required: 770.2735714585964 s
# ---------
#
#
# Target Ratio: 7.0
# Sky background rate per pixel: 0.015282593718181307 1 / s
# Source Photon Rate: 0.18994490478356899 1 / s
#
# Exposure Required: 772.0838352223591 s
# ---------
#
#
# Target Ratio: 7.5
# Sky background rate per pixel: 0.016302917267642443 1 / s
# Source Photon Rate: 0.1906993887542573 1 / s
#
# Exposure Required: 774.1165424362225 s
# ---------
#
#
# Target Ratio: 8.0
# Sky background rate per pixel: 0.017326424640743278 1 / s
# Source Photon Rate: 0.1914051613745408 1 / s
#
# Exposure Required: 776.3413918789803 s
# ---------
#
#
# Target Ratio: 8.5
# Sky background rate per pixel: 0.01835294522093193 1 / s
# Source Photon Rate: 0.1920681328439657 1 / s
#
# Exposure Required: 778.7338530436934 s
# ---------
#
#
# Target Ratio: 9.0
# Sky background rate per pixel: 0.019382325320709208 1 / s
# Source Photon Rate: 0.19269319897185352 1 / s
#
# Exposure Required: 781.2738001814727 s
# ---------
#
#
# Target Ratio: 9.5
# Sky background rate per pixel: 0.020414425855982823 1 / s
# Source Photon Rate: 0.19328446080672 1 / s
#
# Exposure Required: 783.9445257219649 s
# ---------
#
#
# Target Ratio: 10.0
# Sky background rate per pixel: 0.021449120410794553 1 / s
# Source Photon Rate: 0.1938453878646194 1 / s
#
# Exposure Required: 786.7320137074145 s
# ---------
#
#
# Target Ratio: 10.5
# Sky background rate per pixel: 0.022486293618502445 1 / s
# Source Photon Rate: 0.19437894149124374 1 / s
#
# Exposure Required: 789.6243954136631 s
# ---------
#
#
# Target Ratio: 11.0
# Sky background rate per pixel: 0.023525839800142005 1 / s
# Source Photon Rate: 0.1948876694997502 1 / s
#
# Exposure Required: 792.6115351557552 s
# ---------
#
#
# Target Ratio: 11.5
# Sky background rate per pixel: 0.024567661812653435 1 / s
# Source Photon Rate: 0.19537377975441442 1 / s
#
# Exposure Required: 795.6847107654546 s
# ---------
#
#
# Target Ratio: 12.0
# Sky background rate per pixel: 0.0256116700692139 1 / s
# Source Photon Rate: 0.19583919808221567 1 / s
#
# Exposure Required: 798.8363640105689 s
# ---------
#
#
# Target Ratio: 12.5
# Sky background rate per pixel: 0.02665778170146397 1 / s
# Source Photon Rate: 0.19628561435469796 1 / s
#
# Exposure Required: 802.0599034288939 s
# ---------
#
#
# Target Ratio: 13.0
# Sky background rate per pixel: 0.027705919839363463 1 / s
# Source Photon Rate: 0.19671451952642596 1 / s
#
# Exposure Required: 805.349546954863 s
# ---------
#
#
# Target Ratio: 13.5
# Sky background rate per pixel: 0.028756012989095914 1 / s
# Source Photon Rate: 0.1971272356795283 1 / s
#
# Exposure Required: 808.7001951165358 s
# ---------
#
#
# Target Ratio: 14.0
# Sky background rate per pixel: 0.02980799449314047 1 / s
# Source Photon Rate: 0.1975249406016059 1 / s
#
# Exposure Required: 812.1073279743795 s
# ---------
#
#
# Target Ratio: 14.5
# Sky background rate per pixel: 0.03086180205956141 1 / s
# Source Photon Rate: 0.19790868804880277 1 / s
#
# Exposure Required: 815.5669206838147 s
# ---------
#
#
# Target Ratio: 15.0
# Sky background rate per pixel: 0.03191737734990032 1 / s
# Source Photon Rate: 0.1982794245722942 1 / s
#
# Exposure Required: 819.0753738021901 s
# ---------
#
#
# Target Ratio: 15.5
# Sky background rate per pixel: 0.03297466561692339 1 / s
# Source Photon Rate: 0.19863800358471198 1 / s
#
# Exposure Required: 822.6294553691033 s
# ---------
#
#
# Target Ratio: 16.0
# Sky background rate per pixel: 0.034033615384977935 1 / s
# Source Photon Rate: 0.19898519719257773 1 / s
#
# Exposure Required: 826.2262524625684 s
# ---------
#
#
# Target Ratio: 16.5
# Sky background rate per pixel: 0.0350941781669267 1 / s
# Source Photon Rate: 0.19932170620742498 1 / s
#
# Exposure Required: 829.8631304384629 s
# ---------
#
#
# Target Ratio: 17.0
# Sky background rate per pixel: 0.036156308212614195 1 / s
# Source Photon Rate: 0.19964816866200258 1 / s
#
# Exposure Required: 833.5376984429184 s
# ---------
#
#
# Target Ratio: 17.5
# Sky background rate per pixel: 0.03721996228462468 1 / s
# Source Photon Rate: 0.19996516709168446 1 / s
#
# Exposure Required: 837.2477800793823 s
# ---------
#
#
# Target Ratio: 18.0
# Sky background rate per pixel: 0.03828509945775259 1 / s
# Source Photon Rate: 0.20027323478989045 1 / s
#
# Exposure Required: 840.991388337153 s
# ---------
#
#
# Target Ratio: 18.5
# Sky background rate per pixel: 0.03935168093915042 1 / s
# Source Photon Rate: 0.20057286120625356 1 / s
#
# Exposure Required: 844.7667040630703 s
# ---------
#
#
# Target Ratio: 19.0
# Sky background rate per pixel: 0.040419669906570824 1 / s
# Source Photon Rate: 0.20086449662475694 1 / s
#
# Exposure Required: 848.572057394947 s
# ---------
#
#
# Target Ratio: 19.5
# Sky background rate per pixel: 0.0414890313624949 1 / s
# Source Photon Rate: 0.20114855623410077 1 / s
#
# Exposure Required: 852.4059116832746 s
# ---------
#
#
# Target Ratio: 20.0
# Sky background rate per pixel: 0.0425597320022526 1 / s
# Source Photon Rate: 0.20142542368265637 1 / s
#
# Exposure Required: 856.2668495134297 s
# ---------
#
#
# Target Ratio: 20.5
# Sky background rate per pixel: 0.043631740094504136 1 / s
# Source Photon Rate: 0.20169545419439372 1 / s
#
# Exposure Required: 860.1535605090698 s
# ---------
#
#
# Target Ratio: 21.0
# Sky background rate per pixel: 0.044705025372673596 1 / s
# Source Photon Rate: 0.20195897730928067 1 / s
#
# Exposure Required: 864.0648306524166 s
# ---------
#
#
# Target Ratio: 21.5
# Sky background rate per pixel: 0.045779558936112956 1 / s
# Source Photon Rate: 0.20221629930118634 1 / s
#
# Exposure Required: 867.999532901621 s
# ---------
#
#
# Target Ratio: 22.0
# Sky background rate per pixel: 0.04685531315993445 1 / s
# Source Photon Rate: 0.20246770531778713 1 / s
#
# Exposure Required: 871.9566189215308 s
# ---------
#
#
# Target Ratio: 22.5
# Sky background rate per pixel: 0.047932261612584334 1 / s
# Source Photon Rate: 0.20271346127996903 1 / s
#
# Exposure Required: 875.9351117737181 s
# ---------
#
#
# Target Ratio: 23.0
# Sky background rate per pixel: 0.04901037898034784 1 / s
# Source Photon Rate: 0.20295381557245137 1 / s
#
# Exposure Required: 879.9340994358644 s
# ---------
#
#
# Target Ratio: 23.5
# Sky background rate per pixel: 0.05008964099807335 1 / s
# Source Photon Rate: 0.20318900055257821 1 / s
#
# Exposure Required: 883.952729040584 s
# ---------
#
#
# Target Ratio: 24.0
# Sky background rate per pixel: 0.05117002438549087 1 / s
# Source Photon Rate: 0.20341923390025252 1 / s
#
# Exposure Required: 887.9902017403389 s
# ---------
#
#
# Target Ratio: 24.5
# Sky background rate per pixel: 0.05225150678857202 1 / s
# Source Photon Rate: 0.20364471982867088 1 / s
#
# Exposure Required: 892.0457681188608 s
# ---------
#
#
# Target Ratio: 25.0
# Sky background rate per pixel: 0.053334066725444405 1 / s
# Source Photon Rate: 0.20386565017273492 1 / s
#
# Exposure Required: 896.1187240810231 s
# ---------

# %%
plt.scatter(all_rej, all_exp)
plt.xlim(min(all_rej)*0.1, max(all_rej)*1.1)
plt.ylabel('Required Exposure (sec)')
plt.xlabel('Out-of-band rejection')
plt.show()

# %%
# Loop for Medium zodiacal background
siglimit=10.
for config in [11, 12, 13, 14]:

    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2 + point_jitter**2)**0.5


    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,med_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 11
# Name: Small Focal Plane CMOS
# Entrance Pupil diameter 26.0 cm
# Optical Effifiency 0.7893639053254439
# PSF FWHM 4.288 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 23.1 cm
# Effective Area 419.09631397051237 cm2
#
# Effective PSF size 4.83600496277661 arcsec
# Number of effective bgd pixels: 1.6784996136011912
#
# Sky background rate per pixel: 0.023509532912962868 1 / s
# Source Photon Rate: 0.2853421817400859 1 / s
#
# Exposure Required: 476.7554163131319 s
# ---------
#
#
#
# Telescope Configuration 12
# Name: Swiss Cross CMOS
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5232111111111111
# PSF FWHM 2.8800000000000003 arcsec
# Pixel size 4.0 arcsec
# Effective Aperture 21.7 cm
# Effective Area 369.83614116222435 cm2
#
# Effective PSF size 3.6461486530310308 arcsec
# Number of effective bgd pixels: 2.2959750546552984
#
# Sky background rate per pixel: 0.008104002069472175 1 / s
# Source Photon Rate: 0.25180333944189387 1 / s
#
# Exposure Required: 545.884223463544 s
# ---------
#
#
#
# Telescope Configuration 13
# Name: Swiss Cross CCD
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.45337777777777777
# PSF FWHM 6.687692307692308 arcsec
# Pixel size 5.4 arcsec
# Effective Aperture 20.2 cm
# Effective Area 320.4738665926948 cm2
#
# Effective PSF size 7.051611759191432 arcsec
# Number of effective bgd pixels: 4.658800673483091
#
# Sky background rate per pixel: 0.012798242987893105 1 / s
# Source Photon Rate: 0.21819498104837728 1 / s
#
# Exposure Required: 802.9177966240603 s
# ---------
#
#
#
# Telescope Configuration 14
# Name: Medium Focal Plane (CMOS 6k x 6k)
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5675111111111112
# PSF FWHM 3.053 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 22.6 cm
# Effective Area 401.14996593688073 cm2
#
# Effective PSF size 3.7842844766217034 arcsec
# Number of effective bgd pixels: 2.1713364793585552
#
# Sky background rate per pixel: 0.010158132710611384 1 / s
# Source Photon Rate: 0.2731233911387834 1 / s
#
# Exposure Required: 500.4060135649355 s
# ---------

# %%
# Loop for high zodiacal background
siglimit=10.
for config in [11, 12, 13, 14]:

    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2 + point_jitter**2)**0.5



    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,high_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 11
# Name: Small Focal Plane CMOS
# Entrance Pupil diameter 26.0 cm
# Optical Effifiency 0.7893639053254439
# PSF FWHM 4.288 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 23.1 cm
# Effective Area 419.09631397051237 cm2
#
# Effective PSF size 4.83600496277661 arcsec
# Number of effective bgd pixels: 1.6784996136011912
#
# Sky background rate per pixel: 0.12810237338095642 1 / s
# Source Photon Rate: 0.2853421817400859 1 / s
#
# Exposure Required: 669.9329662339885 s
# ---------
#
#
#
# Telescope Configuration 12
# Name: Swiss Cross CMOS
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5232111111111111
# PSF FWHM 2.8800000000000003 arcsec
# Pixel size 4.0 arcsec
# Effective Aperture 21.7 cm
# Effective Area 369.83614116222435 cm2
#
# Effective PSF size 3.6461486530310308 arcsec
# Number of effective bgd pixels: 2.2959750546552984
#
# Sky background rate per pixel: 0.04415833793155241 1 / s
# Source Photon Rate: 0.25180333944189387 1 / s
#
# Exposure Required: 656.3462997258237 s
# ---------
#
#
#
# Telescope Configuration 13
# Name: Swiss Cross CCD
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.45337777777777777
# PSF FWHM 6.687692307692308 arcsec
# Pixel size 5.4 arcsec
# Effective Aperture 20.2 cm
# Effective Area 320.4738665926948 cm2
#
# Effective PSF size 7.051611759191432 arcsec
# Number of effective bgd pixels: 4.658800673483091
#
# Sky background rate per pixel: 0.0697370427530399 1 / s
# Source Photon Rate: 0.21819498104837728 1 / s
#
# Exposure Required: 1278.4914881401385 s
# ---------
#
#
#
# Telescope Configuration 14
# Name: Medium Focal Plane (CMOS 6k x 6k)
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5675111111111112
# PSF FWHM 3.053 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 22.6 cm
# Effective Area 401.14996593688073 cm2
#
# Effective PSF size 3.7842844766217034 arcsec
# Number of effective bgd pixels: 2.1713364793585552
#
# Sky background rate per pixel: 0.05535120217682148 1 / s
# Source Photon Rate: 0.2731233911387834 1 / s
#
# Exposure Required: 612.7556298511042 s
# ---------

# %%
#### Loop for high zodiacal background, 5-sigma
siglimit=5.0
for config in [11, 12, 13, 14]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2 + point_jitter**2)**0.5



    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,high_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 11
# Name: Small Focal Plane CMOS
# Entrance Pupil diameter 26.0 cm
# Optical Effifiency 0.7893639053254439
# PSF FWHM 4.288 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 23.1 cm
# Effective Area 419.09631397051237 cm2
#
# Effective PSF size 4.83600496277661 arcsec
# Number of effective bgd pixels: 1.6784996136011912
#
# Sky background rate per pixel: 0.12810237338095642 1 / s
# Source Photon Rate: 0.2853421817400859 1 / s
#
# Exposure Required: 200.0163620656519 s
# ---------
#
#
#
# Telescope Configuration 12
# Name: Swiss Cross CMOS
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5232111111111111
# PSF FWHM 2.8800000000000003 arcsec
# Pixel size 4.0 arcsec
# Effective Aperture 21.7 cm
# Effective Area 369.83614116222435 cm2
#
# Effective PSF size 3.6461486530310308 arcsec
# Number of effective bgd pixels: 2.2959750546552984
#
# Sky background rate per pixel: 0.04415833793155241 1 / s
# Source Photon Rate: 0.25180333944189387 1 / s
#
# Exposure Required: 215.03749812981187 s
# ---------
#
#
#
# Telescope Configuration 13
# Name: Swiss Cross CCD
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.45337777777777777
# PSF FWHM 6.687692307692308 arcsec
# Pixel size 5.4 arcsec
# Effective Aperture 20.2 cm
# Effective Area 320.4738665926948 cm2
#
# Effective PSF size 7.051611759191432 arcsec
# Number of effective bgd pixels: 4.658800673483091
#
# Sky background rate per pixel: 0.0697370427530399 1 / s
# Source Photon Rate: 0.21819498104837728 1 / s
#
# Exposure Required: 396.2961725533596 s
# ---------
#
#
#
# Telescope Configuration 14
# Name: Medium Focal Plane (CMOS 6k x 6k)
# Entrance Pupil diameter 30.0 cm
# Optical Effifiency 0.5675111111111112
# PSF FWHM 3.053 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 22.6 cm
# Effective Area 401.14996593688073 cm2
#
# Effective PSF size 3.7842844766217034 arcsec
# Number of effective bgd pixels: 2.1713364793585552
#
# Sky background rate per pixel: 0.05535120217682148 1 / s
# Source Photon Rate: 0.2731233911387834 1 / s
#
# Exposure Required: 197.97495998317038 s
# ---------

# %%
x = False
if x:
    print('yes')
