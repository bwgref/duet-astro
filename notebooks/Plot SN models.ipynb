# %%
# %load_ext autoreload
# %autoreload 2
import astropy.units as u

from astroduet import models
sims = models.Simulations()

import numpy as np
from matplotlib import pyplot as plt
from astropy.visualization import quantity_support
import matplotlib
font = {'family' : 'sans',
        'weight' : 'bold',
        'size'   : 18}

matplotlib.rc('font', **font)

dist_check = 375 * u.Mpc
early = 1
late = 7
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#sims.parse_sne_rsg()

# %%
for rsg in sims.sne_rsg_simulations:
    print(rsg)
    fits_file = models.fits_file(rsg)
#    print(fits_file)
    
    rsg_model = models.load_model_ABmag(fits_file, dist=dist_check)
    days = rsg_model[0].to(u.d)


    plt.plot(days, rsg_model[1])
    
    in_range = np.where((days.value > early) & (days.value < late))
    print(rsg_model[1][in_range].mean())
    
    print()

    
plt.xlim(0.01, 21)
plt.ylim([25, 19])
plt.xlabel('Days')
plt.ylabel('Model DUET1 mag')
plt.xscale('Log')
# Out:
# rsg400.dat
# 21.88387978695664 mag(AB)
#
# rsg450.dat
# 21.74445228433923 mag(AB)
#
# rsg500.dat
# 21.62518794337321 mag(AB)
#
# rsg550.dat
# 21.521190159285823 mag(AB)
#
# rsg600.dat
# 21.428934980889547 mag(AB)
#
# rsg650.dat
# 21.345958620392118 mag(AB)
#
# rsg700.dat
# 21.27037474231089 mag(AB)
#
# rsg750.dat
# 21.200755174498276 mag(AB)
#
# rsg800.dat
# 21.136037217065493 mag(AB)
#
# rsg850.dat
# 21.075447178784557 mag(AB)
#
# rsg900.dat
# 21.018238928088504 mag(AB)
#
# rsg950.dat
# 20.963879280821473 mag(AB)
#
# rsg1000.dat
# 20.91029852982701 mag(AB)

# %%
for rsg in sims.sne_rsg_simulations:
    print(rsg)
    fits_file = models.fits_file(rsg)
#    print(fits_file)
    
    rsg_model = models.load_model_ABmag(fits_file, dist=dist_check)
    days = rsg_model[0].to(u.d)
    plt.plot(days, rsg_model[2])
    
    in_range = np.where((days.value > early) & (days.value < late))
    print(rsg_model[2][in_range].mean())
    print()
plt.xlim(0.01, 21)
plt.ylim([25, 19])
plt.xlabel('Days')
plt.ylabel('Model DUET2 mag')
plt.xscale('Log')
# Out:
# rsg400.dat
# 21.641387788695386 mag(AB)
#
# rsg450.dat
# 21.55423109106744 mag(AB)
#
# rsg500.dat
# 21.479458697561 mag(AB)
#
# rsg550.dat
# 21.413937136596164 mag(AB)
#
# rsg600.dat
# 21.35539225818126 mag(AB)
#
# rsg650.dat
# 21.302272254839266 mag(AB)
#
# rsg700.dat
# 21.25337528268467 mag(AB)
#
# rsg750.dat
# 21.20779858021889 mag(AB)
#
# rsg800.dat
# 21.164890544889307 mag(AB)
#
# rsg850.dat
# 21.124203605221776 mag(AB)
#
# rsg900.dat
# 21.08525522617732 mag(AB)
#
# rsg950.dat
# 21.047726060964973 mag(AB)
#
# rsg1000.dat
# 21.00940041474334 mag(AB)
