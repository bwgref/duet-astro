# %%
import astropy.units as u
from tdsat_telescope import load_telescope_parameters
from tdsat_sensitivity import src_rate, bgd_sky_qe_rate, bgd_electronics, calc_exposure
from tdsat_neff import get_neff

# %%
siglimit = 5. # sigma
read_noise = 7. # Read noise

# Target value
AB = 22*u.ABmag

outofband_rejection = 1e-3
point_drift = 5*u.arcsec # To be added to the PSF in quadrature

# Define bands
td1_band = [180, 220]*u.nm
td2_band = [260, 320]*u.nm


# Transmission efficiency
trans_eff = (0.95)**4 # from Mike
reflectivity = 0.85 # From the curve in Jim's slides

# trans_eff = 1.0
# reflectivity=1.0

# %%
# Loop for low zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Get the sky background rate
#    bgd_ph_rate, bgd_elec_rate = bgd_sky_rate(diag=True,
#                                              diameter=diameter,
#                                              band=td1_band,
#                                              pixel_size=pixel_size)

    bgd_ph_rate = bgd_sky_qe_rate(diag=True,
                              diameter=diameter, band=td1_band, pixel_size=pixel_size)
    
    
    # Get the integrated out-of-band sky flux
#    out_of_band_ph_rate, out_of_band_bgd_elec_rate = outofband_bgd_sky_rate(diag=False,
#                                                                            diameter=diameter,
#                                                                            band=td1_band,
#                                                                            pixel_size=pixel_size)
    print()

#    bgd_cps = trans_eff * reflectivity*efficiency*(qe*bgd_ph_rate + outofband_rejection*out_of_band_ph_rate)
    bgd_cps = trans_eff * reflectivity * efficiency * qe * bgd_ph_rate

    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=True,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency * qe * src_ph_rate
    exposure = calc_exposure(10., src_cps, bgd_cps,read_noise, neff)
    print(exposure)
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 33.0 cm
# Telescope aperture: 855.2985999398212 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
# Pixel Area: 18.49 arcsec2
# Rate 0.02905611808284654 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 33.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 9.209330815811809 eV / s
# Photons per second:  1.4855652589930268 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
#
# 537.045804893054 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 24.0 cm
# Telescope aperture: 452.3893421169302 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
# Pixel Area: 18.49 arcsec2
# Rate 0.015368525266960153 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 24.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.8710510100161635 eV / s
# Photons per second:  0.7857535254177993 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
#
# 741.2118901408014 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 32.0 cm
# Telescope aperture: 804.247719318987 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Rate 0.06052470836461155 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 32.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 8.659646240028735 eV / s
# Photons per second:  1.3968951562983098 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
#
# 651.4167957332944 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 21.0 cm
# Telescope aperture: 346.3605900582747 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
# Pixel Area: 18.49 arcsec2
# Rate 0.011766527157516367 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 21.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 3.729398429543625 eV / s
# Photons per second:  0.6015925428980026 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
#
# 1012.3013136180888 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 14.0 cm
# Telescope aperture: 153.93804002589985 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
# Pixel Area: 18.49 arcsec2
# Rate 0.00522956762556283 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 14.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 1.6575104131305 eV / s
# Photons per second:  0.26737446351022337 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
#
# 3952.1214098837418 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 22.0 cm
# Telescope aperture: 380.132711084365 cm2
# Background fluence per arcsec2 1.8373120337339997e-06 1 / (arcsec2 cm2 s)
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Rate 0.028607381687960932 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 22.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.093035918138582 eV / s
# Photons per second:  0.660251226219123 1 / s
# Photons per second per cm2:  0.0017368966336406386 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
#
# 926.2654635213718 s
# ---------

# %%
# Loop for low zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Get the sky background rate
    bgd_ph_rate, bgd_elec_rate = bgd_sky_rate(diag=True,med_zodi=True,
                                              diameter=diameter,
                                              band=td1_band,
                                              pixel_size=pixel_size)

    
    # Get the integrated out-of-band sky flux
    out_of_band_ph_rate, out_of_band_bgd_elec_rate = outofband_bgd_sky_rate(diag=False,med_zodi=True,
                                                                            diameter=diameter,
                                                                            band=td1_band,
                                                                            pixel_size=pixel_size)
    print()

    bgd_cps = trans_eff * reflectivity*efficiency*(qe*bgd_ph_rate + outofband_rejection*out_of_band_ph_rate)


    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=True,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency * qe * src_ph_rate
    exposure = calc_exposure(10., src_cps, bgd_cps,read_noise, neff)
    print(exposure)
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 33.0 cm
# Telescope aperture: 855.2985999398212 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 27.06654600246942 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.013972474753567294 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 33.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 9.209330815811809 eV / s
# Photons per second:  1.4855652589930268 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
#
# 608.5479426428287 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 24.0 cm
# Telescope aperture: 452.3893421169302 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 27.06654600246942 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.007390399869655426 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 24.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.8710510100161635 eV / s
# Photons per second:  0.7857535254177993 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
#
# 797.0259377233291 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 32.0 cm
# Telescope aperture: 804.247719318987 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 26.202988410447915 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Photons 0.02910505653853364 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 32.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 8.659646240028735 eV / s
# Photons per second:  1.3968951562983098 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
#
# 878.0520969049553 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 21.0 cm
# Telescope aperture: 346.3605900582747 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 27.06654600246942 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.005658274900204937 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 21.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 3.729398429543625 eV / s
# Photons per second:  0.6015925428980026 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
#
# 1085.8511373088124 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 14.0 cm
# Telescope aperture: 153.93804002589985 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 27.06654600246942 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.002514788844535527 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 14.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 1.6575104131305 eV / s
# Photons per second:  0.26737446351022337 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
#
# 4262.731984453932 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 22.0 cm
# Telescope aperture: 380.132711084365 cm2
# Fλ total per arcsec2 2.193842267111206e-20 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 26.202988410447915 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Photons 0.01375668687954129 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 22.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.093035918138582 eV / s
# Photons per second:  0.660251226219123 1 / s
# Photons per second per cm2:  0.0017368966336406386 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
#
# 1109.041926472231 s
# ---------

# %%
# Loop for low zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Get the sky background rate
    bgd_ph_rate, bgd_elec_rate = bgd_sky_rate(diag=True,high_zodi=True,
                                              diameter=diameter,
                                              band=td1_band,
                                              pixel_size=pixel_size)

    
    # Get the integrated out-of-band sky flux
    out_of_band_ph_rate, out_of_band_bgd_elec_rate = outofband_bgd_sky_rate(diag=False,high_zodi=True,
                                                                            diameter=diameter,
                                                                            band=td1_band,
                                                                            pixel_size=pixel_size)
    print()

    bgd_cps = trans_eff * reflectivity*efficiency*(qe*bgd_ph_rate + outofband_rejection*out_of_band_ph_rate)


    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=True,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency * qe * src_ph_rate
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print(exposure)
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 33.0 cm
# Telescope aperture: 855.2985999398212 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 23.813971013309466 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.27944949507134587 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 33.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 9.209330815811809 eV / s
# Photons per second:  1.4855652589930268 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 855.2985999398212 cm2
#
# 861.6939751635878 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 24.0 cm
# Telescope aperture: 452.3893421169302 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 23.813971013309466 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.14780799739310854 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 24.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.8710510100161635 eV / s
# Photons per second:  0.7857535254177993 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 452.3893421169302 cm2
#
# 747.8393555540007 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 32.0 cm
# Telescope aperture: 804.247719318987 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 22.950413421287962 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Photons 0.5821011307706726 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 32.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 8.659646240028735 eV / s
# Photons per second:  1.3968951562983098 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 804.247719318987 cm2
#
# 2290.3848689048227 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 21.0 cm
# Telescope aperture: 346.3605900582747 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 23.813971013309466 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.11316549800409872 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 21.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 3.729398429543625 eV / s
# Photons per second:  0.6015925428980026 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 346.3605900582747 cm2
#
# 994.2725593022448 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 14.0 cm
# Telescope aperture: 153.93804002589985 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 23.813971013309466 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
# Pixel Area: 18.49 arcsec2
# Photons 0.05029577689071055 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 14.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 1.6575104131305 eV / s
# Photons per second:  0.26737446351022337 1 / s
# Photons per second per cm2:  0.0017368966336406388 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 153.93804002589985 cm2
#
# 4119.483229254534 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Background Computation Integrating over Pixel Area
# Telescope diameter: 22.0 cm
# Telescope aperture: 380.132711084365 cm2
# Fλ total per arcsec2 4.387684534222412e-19 erg / (Angstrom arcsec2 cm2 s)
# Fλ ABmag per pixel 22.950413421287962 mag(AB)
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
# Pixel Area: 40.96000000000001 arcsec2
# Photons 0.2751337375908258 1 / s
#
#
# Source Computation Integrating over PSF
# Telescope Diameter: 22.0 cm
# Fλ 4.312813831141789e-17 erg / (Angstrom cm2 s)
# ReceivedPower: 4.093035918138582 eV / s
# Photons per second:  0.660251226219123 1 / s
# Photons per second per cm2:  0.0017368966336406386 1 / (cm2 s)
# Fλ ABmag 22.0 mag(AB)
# Eff λ 200.0 nm
# Bandpass: 40.0 nm
# Collecting Area: 380.132711084365 cm2
#
# 1946.3889670647989 s
# ---------
