# %%
import astropy.units as u
from tdsat_telescope import load_telescope_parameters
from tdsat_sensitivity import src_rate, bgd_sky_qe_rate, bgd_electronics, calc_exposure
from tdsat_neff import get_neff

# %%
siglimit = 10. # sigma
read_noise = 7. # Read noise

# Target value
AB = 22*u.ABmag

rejection = 1e-3
point_drift = 5*u.arcsec # To be added to the PSF in quadrature

# Define bands
td1_band = [180, 220]*u.nm
td2_band = [260, 320]*u.nm


# Transmission efficiency
trans_eff = (0.95)**4 # from Mike
reflectivity = 0.85 # From the curve in Jim's slides

# trans_eff = 1.0
# reflectivity=1.0

# %%
# Loop for low zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size, rejection=rejection)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Sky background rate per pixel: 0.017751965556614343 1 / s
# Source Photon Rate: 0.6353289267405973 1 / s
#
# Exposure Required: 549.1714479303116 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Sky background rate per pixel: 0.008459615136635902 1 / s
# Source Photon Rate: 0.302762991977236 1 / s
#
# Exposure Required: 750.8494454393777 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Sky background rate per pixel: 0.0390717671946995 1 / s
# Source Photon Rate: 0.6312366415621118 1 / s
#
# Exposure Required: 688.3545928613759 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Sky background rate per pixel: 0.0060517392674322825 1 / s
# Source Photon Rate: 0.21658700279863374 1 / s
#
# Exposure Required: 1025.012309881202 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Sky background rate per pixel: 0.0016322202669952583 1 / s
# Source Photon Rate: 0.05841588342018645 1 / s
#
# Exposure Required: 4005.6979223968015 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Sky background rate per pixel: 0.017365229864310897 1 / s
# Source Photon Rate: 0.2805496184720498 1 / s
#
# Exposure Required: 957.0101163935907 s
# ---------

# %%
# Loop for Medium zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,med_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Sky background rate per pixel: 0.06881195663367852 1 / s
# Source Photon Rate: 0.6353289267405973 1 / s
#
# Exposure Required: 675.1801631759251 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Sky background rate per pixel: 0.032792012133152346 1 / s
# Source Photon Rate: 0.302762991977236 1 / s
#
# Exposure Required: 847.2878888957711 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Sky background rate per pixel: 0.15145391879160547 1 / s
# Source Photon Rate: 0.6312366415621118 1 / s
#
# Exposure Required: 1100.3952969802172 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Sky background rate per pixel: 0.023458361199541537 1 / s
# Source Photon Rate: 0.21658700279863374 1 / s
#
# Exposure Required: 1151.9703951204592 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Sky background rate per pixel: 0.006326976574559661 1 / s
# Source Photon Rate: 0.05841588342018645 1 / s
#
# Exposure Required: 4543.041691458526 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Sky background rate per pixel: 0.06731285279626911 1 / s
# Source Photon Rate: 0.2805496184720498 1 / s
#
# Exposure Required: 1281.0564524507645 s
# ---------

# %%
# Loop for high zodiacal background
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,high_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Sky background rate per pixel: 1.3739328047918216 1 / s
# Source Photon Rate: 0.6353289267405973 1 / s
#
# Exposure Required: 5223.375912010238 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Sky background rate per pixel: 0.6547411730306582 1 / s
# Source Photon Rate: 0.302762991977236 1 / s
#
# Exposure Required: 4133.143209024338 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Sky background rate per pixel: 3.024002188308933 1 / s
# Source Photon Rate: 0.6312366415621118 1 / s
#
# Exposure Required: 14709.019962582934 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Sky background rate per pixel: 0.46838098457632527 1 / s
# Source Photon Rate: 0.21658700279863374 1 / s
#
# Exposure Required: 5454.669833105488 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Sky background rate per pixel: 0.12632747412217 1 / s
# Source Photon Rate: 0.05841588342018645 1 / s
#
# Exposure Required: 22964.877308868912 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Sky background rate per pixel: 1.3440009725817483 1 / s
# Source Photon Rate: 0.2805496184720498 1 / s
#
# Exposure Required: 12163.717770340543 s
# ---------

# %%
# Loop for high zodiacal background, 5-sigma
siglimit=5.0
for config in [5, 7, 9, 6, 8, 10]:
    print()
    diameter, qe, psf_size, pixel_size, efficiency = load_telescope_parameters(config, diag=True)

    # Arbitrarily set QE to 0.7
    qe=0.7
    
    # Add pointing drift to the PSF in quadrature.
    psf_size = (psf_size**2 + point_drift**2)**0.5

    print()
    print('Effective PSF size {}'.format(psf_size))
    # Get the number of effective background pixels
    neff = get_neff(psf_size, pixel_size)
    print('Number of effective bgd pixels: {}'.format(neff))
    print()

    # Compute sky background
    bgd_ph_rate = bgd_sky_qe_rate(diag=False,high_zodi=True,
                                  diameter=diameter,
                                  band=td1_band,
                                  pixel_size=pixel_size)
    bgd_cps = trans_eff * reflectivity * efficiency * bgd_ph_rate
    print('Sky background rate per pixel: {}'.format(bgd_cps))
    
    # Get the source rate:
    src_ph_rate, src_elec_rate = src_rate(diag=False,ABmag=AB,
                                          diameter=diameter)

    src_cps = trans_eff * reflectivity * efficiency *qe* src_ph_rate
    print('Source Photon Rate: {}'.format(src_cps))
    print()
    exposure = calc_exposure(siglimit, src_cps, bgd_cps,read_noise, neff)
    print('Exposure Required: {}'.format(exposure))
    print('---------')
    print()
    print()
# Out:
# Telescope Configuration 5
# Name: Big Schmidt
# Entrance Pupil diameter 33.0 cm
# Optical Effifiency 0.8824609733700643
# PSF FWHM 9.288 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 31.0 cm
# Effective Area 754.7676350249478 cm2
#
# Effective PSF size 10.548314746915738 arcsec
# Number of effective bgd pixels: 14.782224779232394
#
# Sky background rate per pixel: 1.3739328047918216 1 / s
# Source Photon Rate: 0.6353289267405973 1 / s
#
# Exposure Required: 1330.9617333840902 s
# ---------
#
#
#
# Telescope Configuration 7
# Name: Medium Schmidt
# Entrance Pupil diameter 24.0 cm
# Optical Effifiency 0.7950694444444444
# PSF FWHM 3.268 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 21.4 cm
# Effective Area 359.6809429094954 cm2
#
# Effective PSF size 5.973259076919399 arcsec
# Number of effective bgd pixels: 5.229400658738859
#
# Sky background rate per pixel: 0.6547411730306582 1 / s
# Source Photon Rate: 0.302762991977236 1 / s
#
# Exposure Required: 1081.0242191566329 s
# ---------
#
#
#
# Telescope Configuration 9
# Name: Fast Schmidt
# Entrance Pupil diameter 32.0 cm
# Optical Effifiency 0.932431640625
# PSF FWHM 28.352 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 30.9 cm
# Effective Area 749.9060203935176 cm2
#
# Effective PSF size 28.78951031191743 arcsec
# Number of effective bgd pixels: 19.1516
#
# Sky background rate per pixel: 3.024002188308933 1 / s
# Source Photon Rate: 0.6312366415621118 1 / s
#
# Exposure Required: 3689.211749373583 s
# ---------
#
#
#
# Telescope Configuration 6
# Name: Two mini Big Schmidts
# Entrance Pupil diameter 21.0 cm
# Optical Effifiency 0.7428798185941043
# PSF FWHM 2.8810000000000002 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 18.1 cm
# Effective Area 257.30429231063806 cm2
#
# Effective PSF size 5.770629168470281 arcsec
# Number of effective bgd pixels: 4.906516266274959
#
# Sky background rate per pixel: 0.46838098457632527 1 / s
# Source Photon Rate: 0.21658700279863374 1 / s
#
# Exposure Required: 1429.7910322331456 s
# ---------
#
#
#
# Telescope Configuration 8
# Name: Two Small "Medium" Schmidts
# Entrance Pupil diameter 14.0 cm
# Optical Effifiency 0.4508163265306123
# PSF FWHM 3.698 arcsec
# Pixel size 4.3 arcsec
# Effective Aperture 9.4 cm
# Effective Area 69.39778171779854 cm2
#
# Effective PSF size 6.218939137827287 arcsec
# Number of effective bgd pixels: 5.64560598674857
#
# Sky background rate per pixel: 0.12632747412217 1 / s
# Source Photon Rate: 0.05841588342018645 1 / s
#
# Exposure Required: 5991.241584506152 s
# ---------
#
#
#
# Telescope Configuration 10
# Name: Mini Fast Schmidts
# Entrance Pupil diameter 22.0 cm
# Optical Effifiency 0.8767768595041323
# PSF FWHM 9.024 arcsec
# Pixel size 6.4 arcsec
# Effective Aperture 20.6 cm
# Effective Area 333.29156461934116 cm2
#
# Effective PSF size 10.316616499608774 arcsec
# Number of effective bgd pixels: 6.8939746349118165
#
# Sky background rate per pixel: 1.3440009725817483 1 / s
# Source Photon Rate: 0.2805496184720498 1 / s
#
# Exposure Required: 3067.0916069530185 s
# ---------
